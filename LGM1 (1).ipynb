# %% [markdown]
# # LetsGrowMore - Data Science Internship
# ## Task 1: Iris Flowers Classification ML Project
# ### Author: Geetanjali Kotkar
# - In this task we classify the flowers on the basis of their respective species. i.e Iris-setosa, Iris-versicolor, Iris-virginica.

# %% [markdown]
# ![WhatsApp%20Image%202022-08-28%20at%2011.25.12%20PM.jpeg](attachment:WhatsApp%20Image%202022-08-28%20at%2011.25.12%20PM.jpeg)

# %% [markdown]
# ## Step 1: Import libraries

# %%
#Import required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# %%
#To ignore warnings

import warnings as wg
wg.filterwarnings("ignore")

# %%
#Read data
df=pd.read_csv('C:/Users/kotka/Downloads/Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.shape
# Out:
# (150, 6)

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
data=df.groupby('Species')

# %%
data.head()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 50    51            7.0           3.2            4.7           1.4
# 51    52            6.4           3.2            4.5           1.5
# 52    53            6.9           3.1            4.9           1.5
# 53    54            5.5           2.3            4.0           1.3
# 54    55            6.5           2.8            4.6           1.5
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# ...

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# ## Step 2: Visualizing the dataset

# %%
plt.boxplot(df['SepalLengthCm'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x281c3235250>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x281c32358b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x281c3216dc0>],
#  'medians': [<matplotlib.lines.Line2D at 0x281c3235fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x281c32413a0>],
#  'means': []}

# %%
plt.boxplot(df['SepalWidthCm'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x281c349f0d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x281c349f7f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x281c348ed00>],
#  'medians': [<matplotlib.lines.Line2D at 0x281c349ff10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x281c34aa2e0>],
#  'means': []}

# %%
plt.boxplot(df['PetalLengthCm'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x281c350a250>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x281c350a850>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x281c34fbe80>],
#  'medians': [<matplotlib.lines.Line2D at 0x281c350aeb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x281c3516280>],
#  'means': []}

# %%
plt.boxplot(df['PetalWidthCm'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x281c35794f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x281c3579c10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x281c35791c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x281c3584370>],
#  'fliers': [<matplotlib.lines.Line2D at 0x281c3584700>],
#  'means': []}

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Step 3: Data Preparation

# %%
df.drop('Id',axis=1,inplace=True)

# %%
sp={'Iris-setosa':1, 'Iris-versicolor':2, 'Iris-virginica':3}

# %%
df.Species=[sp[i] for i in df.Species]

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0              5.1           3.5            1.4           0.2        1
# 1              4.9           3.0            1.4           0.2        1
# 2              4.7           3.2            1.3           0.2        1
# 3              4.6           3.1            1.5           0.2        1
# 4              5.0           3.6            1.4           0.2        1
# ..             ...           ...            ...           ...      ...
# 145            6.7           3.0            5.2           2.3        3
# 146            6.3           2.5            5.0           1.9        3
# 147            6.5           3.0            5.2           2.0        3
# 148            6.2           3.4            5.4           2.3        3
# 149            5.9           3.0            5.1           1.8        3
#
# [150 rows x 5 columns]

# %%
X=df.iloc[:,0:4]   #Independent variables

# %%
X
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
y=df.iloc[:,4]   #dependent variable

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 145    3
# 146    3
# 147    3
# 148    3
# 149    3
# Name: Species, Length: 150, dtype: int64

# %% [markdown]
# ## Step 4: Training the Model

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33,random_state=40)

# %%
model=LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.score(X,y)   #Coefficient of prediction
# Out:
# 0.9304223675331595

# %%
model.coef_
# Out:
# array([-0.10974146, -0.04424045,  0.22700138,  0.60989412])

# %%
model.intercept_
# Out:
# 1.192083994828144

# %% [markdown]
# ## Step 5: Making Predictions

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([0.99358084, 2.38115786, 2.954033  , 3.04163735, 2.17877271,
#        3.08524888, 2.35070534, 2.20435076, 2.40310615, 0.91079163,
#        2.20415981, 1.00008849, 0.96660515, 2.57522972, 1.85593145,
#        3.12946589, 2.59137976, 2.88550825, 2.2654272 , 2.24113634,
#        2.97884018, 3.00431431, 2.1876208 , 0.97833114, 2.05930184,
#        0.96731454, 0.89816529, 2.69236016, 0.91869693, 1.93212811,
#        1.95420588, 1.17725847, 1.10011902, 0.90924548, 0.95181031,
#        2.91785077, 1.03762592, 0.98473275, 2.81075169, 0.95635941,
#        1.01260878, 2.30141848, 2.60005592, 2.90028407, 2.72019374,
#        0.94446591, 3.20111558, 2.58832992, 2.18772685, 0.91869693])

# %% [markdown]
# ## Step 6: Model Evaluation

# %%
print("MEan squared error: %.4f" % np.mean((y_pred - y_test)**2))
# Out:
# MEan squared error: 0.0389

# %% [markdown]
# ## Thank You !
